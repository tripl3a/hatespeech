# %% [markdown]
# # Hatespeech Detection

# %% [markdown]
# Test the connection to the github branch.

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import BaggingClassifier
import sklearn.metrics as skm
from os import chdir
from sklearn import model_selection
import skift

# %%
chdir("/home/arndt/git-reps/hatespeech/")

df_test = pd.merge(pd.read_csv("data/test.csv"),
                   pd.read_csv("data/test_labels.csv"),
                   how="inner",
                   on="id")

df_train=pd.read_csv("data/train.csv")

# data preperation
df_train=df_train[["id","comment_text","toxic"]]
df_train["label"]="__label__not_toxic"
df_train.loc[df_train["toxic"]==1,"label"]="__label__toxic"
df_train["comment_text"]=df_train["comment_text"].apply(str.replace,args=("\n"," "))
df_train["comment_text"]=df_train["comment_text"].apply(str.replace,args=("\"",""))

df_test["comment_text"]=df_test["comment_text"].apply(str.replace,args=("\n"," "))
df_test["comment_text"]=df_test["comment_text"].apply(str.replace,args=("\"",""))

X_train = pd.DataFrame(df_train.loc[:,"comment_text"])
y_train = df_train.loc[:,"toxic"]
X_test = pd.DataFrame(df_test[df_test["toxic"]>-1].loc[:,"comment_text"])
y_test = df_test[df_test["toxic"]>-1].loc[:,"toxic"]

# %% [markdown]
# # Scoring function

# %%
def score_preds(y_true, y_pred):
    print("confusion matrix:")
    print(str(skm.confusion_matrix(y_true, y_pred)))
    print("classification report:")
    print(str(skm.classification_report(y_true, y_pred)))
    print("f1 macro: %0.4f" % (skm.precision_recall_fscore_support(y_true, y_pred, average='macro')[2]))
    print("f1 micro: %0.4f" % (skm.precision_recall_fscore_support(y_true, y_pred, average='micro')[2]))

# %% [markdown]
# # Majority class classifier

# %%
score_preds(y_test, np.zeros(y_test.shape))
# Out:
# confusion matrix:
# [[57888     0]
#  [ 6090     0]]
# classification report:
#              precision    recall  f1-score   support
#
#           0       0.90      1.00      0.95     57888
#           1       0.00      0.00      0.00      6090
#
# avg / total       0.82      0.90      0.86     63978
#
# f1 macro: 0.4750
# f1 micro: 0.9048
# /home/arndt/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# The error here can be ignored.
#
# By only assigning all fitted values to the majority class we get a F1 score of 90%.
#
# This is, because the test dataset is imbalanced and contains only 10% hatespeech comments.

# %% [markdown]
# # Single skift model

# %%
skift_clf = skift.FirstObjFtClassifier(minn=3, maxn=3)
skift_clf.fit(X_train, y_train)

print("score on test data: %0.4f" % (skift_clf.score(X_test, y_test)))
print("score on training data: %0.4f" % (skift_clf.score(X_train, y_train))) #model overfitting on training data?

preds = skift_clf.predict(X_test)
preds_proba = skift_clf.predict_proba(X_test)

score_preds(y_test, preds)
# Out:
# score on test data: 0.9284
# score on training data: 0.9683
# confusion matrix:
# [[54835  3053]
#  [ 1531  4559]]
# classification report:
#              precision    recall  f1-score   support
#
#           0       0.97      0.95      0.96     57888
#           1       0.60      0.75      0.67      6090
#
# avg / total       0.94      0.93      0.93     63978
#
# f1 macro: 0.8127
# f1 micro: 0.9284

# %% [markdown]
# # Single skift model - pretrained vectors
#
# fastText English Word Vectors
# trained on Wikipedia 2017, UMBC webbase corpus, and statmt.org
#
# https://www.kaggle.com/facebook/fasttext-wikinews/data

# %%
skift_clf = skift.FirstObjFtClassifier(minn=3, maxn=3, pretrainedVectors="data/wiki-news-300d-1M.vec")
skift_clf.fit(X_train, y_train)

print("score on test data: %0.4f" % (skift_clf.score(X_test, y_test)))
print("score on training data: %0.4f" % (skift_clf.score(X_train, y_train))) #model overfitting on training data?

preds = skift_clf.predict(X_test)
preds_proba = skift_clf.predict_proba(X_test)

score_preds(y_test, preds)
# Out:
# score on test data: 0.9270
# score on training data: 0.9684
# confusion matrix:
# [[54708  3180]
#  [ 1493  4597]]
# classification report:
#              precision    recall  f1-score   support
#
#           0       0.97      0.95      0.96     57888
#           1       0.59      0.75      0.66      6090
#
# avg / total       0.94      0.93      0.93     63978
#
# f1 macro: 0.8110
# f1 micro: 0.9270

# %% [markdown]
# # Check common errors
# What commonnalities have the false negatives? Check common errors …

# %%
comp = pd.merge(pd.DataFrame({"comment_text" : X_test["comment_text"].values, "toxic_pred" : preds}),
                pd.concat([X_test, y_test], axis=1))

# %% [markdown]
# ## False negatives

# %%
false_negatives = comp[(comp["toxic"]==1) & (comp["toxic_pred"]==0)]
print(false_negatives.shape)
false_negatives["comment_text"].to_csv("data/false_negatives.txt")
false_negatives
# Out:
# (1493, 3)
#                                             comment_text  toxic_pred  toxic
# 8      == Arabs are committing genocide in Iraq, but ...         0.0      1
# 38     How dare you vandalize that page about the HMS...         0.0      1
# 89     :Eek, but shes cute in an earthy kind of way. ...         0.0      1
# 106    ::::Well, it sucks to have a university to be ...         0.0      1
# 127    :::::::::Moi? Ego? I am mortified that you cou...         0.0      1
# 133        So, on the tenth anniversary of 9/11, New ...         0.0      1
# 231    The true truth is that only my balls have offi...         0.0      1
# 279                     Karl Tearle is a mop haired twat         0.0      1
# 294    GIVE BLOWJOBS TO HOT WOMEN FROM ALDERLEY EDGE,...         0.0      1
# 434    That's helpful. MOS be damned, Thecodingprojec...         0.0      1
# 484    == Intolerance in India ==     india is a Gene...         0.0      1
# 541    :* Because the overall aim of the project is w...         0.0      1
# 547    ::Foolish nonsense. I have never had to do som...         0.0      1
# 618              Shut up please, this consensus is over.         0.0      1
# 655        Utterly utterly tiny insignificant anal re...         0.0      1
# 657                         Y una mierda.Tu puta madre''         0.0      1
# 733    == stop being an ass ==    It seems you are a ...         0.0      1
# 760    Sex change and expert are oxy morons.  Almost ...         0.0      1
# 791    :I removed the frog's penis caption. The real ...         0.0      1
# 800    == wtf ==    whoever removed all the great ima...         0.0      1
# 833        someone, please edit this line:    The Leb...         0.0      1
# 1109      ::Alternatively, to maintain the limerick's...         0.0      1
# 1125                  about Roy Keane's dog masturbation         0.0      1
# 1203   ::Tiptoey, your some kind of chump for Goeathe...         0.0      1
# 1219                ==FIRESTAR IS A POWER HUNGRY, ARSE==         0.0      1
# 1291       == Vandalism? ==     Many countries call j...         0.0      1
# 1361   :::Hi Giggy! Puny 'shonen post pile of new fee...         0.0      1
# 1386   ==  I was involved in a lot of articles surrou...         0.0      1
# 1387   Your observations are consistent with those of...         0.0      1
# 1468       == Thanks for the laugh... ==    (→User-re...         0.0      1
# ...                                                  ...         ...    ...
# 62718  The miserable Jew is all over trying to make m...         0.0      1
# 62726  Your spelling seems to be at about the 3rd gra...         0.0      1
# 62727  == Is this list being monitored? ==    It seem...         0.0      1
# 62751  ==NOT EVEN HALF-JEWISH!==    Why do you Jews a...         0.0      1
# 62870     **(< Unindent) Heh... If I look up asshole,...         0.0      1
# 62920  )    ==Someone deletE this garbage==    Honest...         0.0      1
# 62933  You're right CountZero.  I apologize. I've jus...         0.0      1
# 63052  I'm sorry, what nonsense did I add to wikipedi...         0.0      1
# 63060                            I HATE THIS COUNTRY!!!1         0.0      1
# 63094  ...neutral point of view policy? Are you a tee...         0.0      1
# 63105  == |ANAL NECROPHILIA  ==    |ANAL NECROPHILIA ...         0.0      1
# 63149  == Five Finger Death Punch Bathory ==    The i...         0.0      1
# 63197  ==Why?==   Who in their right mind agreed that...         0.0      1
# 63210  :Another Holocaust denier. You might as well b...         0.0      1
# 63255  Im a little BITCH-HelloThereMinions        Any...         0.0      1
# 63276      == Your recent bizarre actions ==    Have ...         0.0      1
# 63297  pair. Maybe then you'll realize how foolish yo...         0.0      1
# 63323     ::Did Obama call a political opponent a can...         0.0      1
# 63325  No, she was a promising and well known young m...         0.0      1
# 63378  What the hell, what would we call her if we wa...         0.0      1
# 63475      :::Really? Wrong to pick up? Heat of the m...         0.0      1
# 63480         Please, someone fix this godawful article.         0.0      1
# 63515  As I am a teenager, I feel the need to say, Sh...         0.0      1
# 63591      == Sperre / Blacklist ==    Hallo, wenn mi...         0.0      1
# 63636  ::::::::Yeah, sure, you say you welcome discus...         0.0      1
# 63735  I guess what I said a few months back about th...         0.0      1
# 63781           Shut up and learn to sign your comments.         0.0      1
# 63782                Baylor kids like to kill themselves         0.0      1
# 63827     :you might mention it was all your fault ou...         0.0      1
# 63962      == IRAN ==   That’s right, Iran. It was ou...         0.0      1
#
# [1493 rows x 3 columns]

# %% [markdown]
# ## False positives

# %%
false_positives = comp[(comp["toxic"]==0) & (comp["toxic_pred"]==1)]
print(false_positives.shape)
false_positives["comment_text"].to_csv("data/false_positives.txt")
false_positives
# Out:
# (3180, 3)
#                                             comment_text  toxic_pred  toxic
# 27     I WILL BURN YOU TO HELL IF YOU REVOKE MY TALK ...         1.0      0
# 60     == hrthrtdghrsdtghtrsdhtrhdgthjrtgh ==    ffff...         1.0      0
# 61     == black mamba ==    It.is ponious snake of th...         1.0      0
# 78         == Shameless Canvass ==    Hello, Diannaa!...         1.0      0
# 79                             WHAT THE HELL      Justin         1.0      0
# 87     ::::Buffoon Synonyms:    bozo, buffo, clown, c...         1.0      0
# 99                                 and lewd sex in China         1.0      0
# 148        ::: You have my trust. But trust me on thi...         1.0      0
# 150        == A little late, but... ==    Andy, I jus...         1.0      0
# 152    , and ISEP is incresing in prestige even more....         1.0      0
# 166    jack dion really bikes karly so much he wants ...         1.0      0
# 180    == Gay? ==   He's gay too. It should be noted ...         1.0      0
# 196    Random /u/ here, just wanted to let everyone k...         1.0      0
# 232    ::::Da si probao pročitati moje promjene vidio...         1.0      0
# 235       :You can't just say, that's crap and remove...         1.0      0
# 262    Well honestly I cant be fucking bothered tonig...         1.0      0
# 269                           :Looks like a Nazi salute.         1.0      0
# 280    they still shouldnt kill a women for a reason ...         1.0      0
# 358    666 the devil will get you all !!!!!!!!!!!!!!!...         1.0      0
# 373                                   You guys are sick!         1.0      0
# 374    == Pavel Fursov ==    Sorry, I left my account...         1.0      0
# 392    Agreed, it is stupid to say that any Malfoy is...         1.0      0
# 433    if you add cocaine to a blunt it is called 51....         1.0      0
# 443    First off I was just joking around with you. G...         1.0      0
# 468                             sex sex nasty un un uhhh         1.0      0
# 508    FJTFBYT6RHDFS6HF NBAAAAAAAAAAAAAAAAAAAAAAAAAAA...         1.0      0
# 540    :Have you not heard? The At&T; guy just had a ...         1.0      0
# 545    DUDE!! OMG!! WHY DOES IT MATTER!? IT WAS RELEA...         1.0      0
# 578            :Are you fucking kidding me—Ryulong (琉竜)          1.0      0
# 582    ''''''''''== REPLY TO ALL THIS SHIT YOUS LOTS ...         1.0      0
# ...                                                  ...         ...    ...
# 63538  Have you ever seen a picture of the guy? Holy ...         1.0      0
# 63549  u guy so obsaessed with wickipidia you cant re...         1.0      0
# 63552  == This is a open and shut case. ==    http://...         1.0      0
# 63563  :::::Oh, I'm looking forward to doing some Val...         1.0      0
# 63569  :Of course. The big bad  would of course be th...         1.0      0
# 63578  ==the torment==    you got your information wr...         1.0      0
# 63619  Barracking the Obama is garbage.  Stop with th...         1.0      0
# 63641  ==Fanatics==    How dare you delete my post be...         1.0      0
# 63704  Dick face magee    diagnosed with manic depres...         1.0      0
# 63724  ::Genau das Verhalten dieses anderen Users ist...         1.0      0
# 63727  Hmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmmm...         1.0      0
# 63752  == ba ha hee buddha ==    I am your god I crea...         1.0      0
# 63770             FAT PEOPLE NEED TO LOSE WEIGHT!!!!!!!!         1.0      0
# 63789  == Anyone for gay sex ==    The decision to re...         1.0      0
# 63798  ::David Lange was NOT a vegan.  A vegan doesn'...         1.0      0
# 63800  == Get a life ==    Witch! Witch!   Sorry, I m...         1.0      0
# 63809  OMFG WTF OMFG WTF OMFG WTF OMFG WTF OMFG WTF O...         1.0      0
# 63834  Mein lieber Brendel, Ich bin auch deutscher He...         1.0      0
# 63836                            == lamo ==    who are u         1.0      0
# 63842     ::I don't have a choice.  RL is fucking wit...         1.0      0
# 63866  get off wikepidia you dorks and get on myspace...         1.0      0
# 63888  Slim Thug is the big boss of the north, not th...         1.0      0
# 63892     ::::If you said Currently, there are stupid...         1.0      0
# 63902  :::I have a question for you, since you are a ...         1.0      0
# 63903  :More like your anti-Semitic rant Citation got...         1.0      0
# 63917     * To quote Something Awful   :Haha! Chuck N...         1.0      0
# 63935          ::Well, now don't I feel stupid....   ·           1.0      0
# 63942  Bill clinton is al-qaeda, its all about gettin...         1.0      0
# 63972  shut down the mexican border withought looking...         1.0      0
# 63975  ==shame on you all!!!==    You want to speak a...         1.0      0
#
# [3180 rows x 3 columns]

# %% [markdown]
# # Ensemble predictions

# %%
# Make predictions with a list of classifiers on dataframe X
def ensemble_predict_proba(classifiers, X):
    proba = [classifier.predict_proba(X) for classifier in classifiers]
    mean = np.zeros(proba[0].shape)
    for i in range(len(classifiers)):
        mean = mean + proba[i]
    mean = mean / float(len(classifiers))
    return mean

def ensemble_predict(classifiers, X):
    kfold_proba = ensemble_predict_proba(classifiers, X)
    kfold_labels = np.zeros(kfold_proba.shape[0]) #initialize array
    kfold_labels[kfold_proba[:,0]<=kfold_proba[:,1]] = 1
    return kfold_labels

# %% [markdown]
# # Build multiple models using K-Folds

# %%
seed = 77
kfold = model_selection.KFold(n_splits=5, random_state=seed)
#kfold = model_selection.KFold(n_splits=3, shuffle=True)

# build multiple models using k folds:
kfold_clfs = list()
for train_index, test_index in kfold.split(df_train):
    X = pd.DataFrame(df_train.loc[:,"comment_text"])
    y = df_train.loc[:,"toxic"]
    clf = skift.FirstObjFtClassifier(minn=3, maxn=3, pretrainedVectors="data/wiki-news-300d-1M.vec")
    clf.fit(X.iloc[train_index], y.iloc[train_index])
    clf.model.quantize()
    print(clf.score(X.iloc[test_index], y.iloc[test_index]))
    kfold_clfs.append(clf)
# Out:
# 0.951464828451
# 0.951118631322
# 0.953061352385
# 0.950742620793
# 0.949144576048

# %%
score_preds(y_test, ensemble_predict(kfold_clfs, X_test))
# Out:
# confusion matrix:
# [[53799  4089]
#  [ 1437  4653]]
# classification report:
#              precision    recall  f1-score   support
#
#           0       0.97      0.93      0.95     57888
#           1       0.53      0.76      0.63      6090
#
# avg / total       0.93      0.91      0.92     63978
#
# f1 macro: 0.7893
# f1 micro: 0.9136

# %% [markdown]
# # StratifiedKFold
# There are different strategies in creating a train set and test set split of your data. If you want to keep the percentage for each class in each fold the same you want to use a stratified split.

# %%
seed = 77
stkfold = model_selection.StratifiedKFold(n_splits=5, random_state=seed)

# build multiple models using k folds:
stkfold_clfs = list()
for train_index, test_index in stkfold.split(X=pd.DataFrame(df_train.loc[:,"comment_text"]), 
                                             y = df_train.loc[:,"toxic"]):
    clf = skift.FirstObjFtClassifier(minn=3, maxn=3, pretrainedVectors="data/wiki-news-300d-1M.vec")
    clf.fit(X.iloc[train_index], y.iloc[train_index])
    clf.model.quantize()
    print(clf.score(X.iloc[test_index], y.iloc[test_index]))
    stkfold_clfs.append(clf)
# Out:
# 0.951214162619
# 0.951809493968
# 0.950178605001
# 0.950617283951
# 0.948923636136

# %%
score_preds(y_test, ensemble_predict(stkfold_clfs, X_test))
# Out:
# confusion matrix:
# [[53721  4167]
#  [ 1428  4662]]
# classification report:
#              precision    recall  f1-score   support
#
#           0       0.97      0.93      0.95     57888
#           1       0.53      0.77      0.62      6090
#
# avg / total       0.93      0.91      0.92     63978
#
# f1 macro: 0.7877
# f1 micro: 0.9125

# %% [markdown]
# I would not balance the data within the folds, as the data will not be balanced in a real-world example. Thus, the cross-validation score will not be represent the model performance well.
#
# Some ways to deal with imbalanced data is under- and over-sampling (e.g. SMOTE).

# %% [markdown]
# # Oversampling (the minority class)

# %%
from collections import Counter
print(sorted(Counter(y_train).items()))
# Out:
# [(0, 144277), (1, 15294)]

# %%
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=0)
X_resampled, y_resampled = ros.fit_sample(X_train, y_train)
print(sorted(Counter(y_resampled).items()))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-6999680ba802> in <module>()
#       1 from imblearn.over_sampling import RandomOverSampler
#       2 ros = RandomOverSampler(random_state=0)
# ----> 3 X_resampled, y_resampled = ros.fit_sample(X_train, y_train)
#       4 print(sorted(Counter(y_resampled).items()))
#
# ~/anaconda3/lib/python3.6/site-packages/imblearn/base.py in fit_sample(self, X, y)
#      86         """
#      87
# ---> 88         return self.fit(X, y).sample(X, y)
#      89
#      90     @abstractmethod
#
# ~/anaconda3/lib/python3.6/site-packages/imblearn/base.py in fit(self, X, y)
#     155
#     156         """
# --> 157         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc'])
#     158         y = check_target_type(y)
#     159         self.X_hash_, self.y_hash_ = hash_X_y(X, y)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     572                     ensure_2d, allow_nd, ensure_min_samples,
# --> 573                     ensure_min_features, warn_on_dtype, estimator)
#     574     if multi_output:
#     575         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     446         # make sure we actually converted to numeric:
#     447         if dtype_numeric and array.dtype.kind == "O":
# --> 448             array = array.astype(np.float64)
#     449         if not allow_nd and array.ndim >= 3:
#     450             raise ValueError("Found array with dim %d. %s expected <= 2."
#
# ValueError: could not convert string to float: " And ... I really don't think you understand.  I came here and my idea was bad right away.  What kind of community goes you have bad ideas go away, instead of helping rewrite them.   "
